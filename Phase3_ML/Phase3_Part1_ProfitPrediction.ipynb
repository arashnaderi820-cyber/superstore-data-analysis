# %% [markdown]
# <h1>پیش‌بینی سود فروش محصولات با استفاده از مدل‌های رگرسیونی</h1>

# %% [markdown]
# <h2>وارد کردن کتابخانه‌ها و مدل‌ها</h2>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import pickle

# %%
result = {}

# %% [markdown]
# <h2>بارگذاری و بررسی اولیه داده‌ها</h2>

# %%
df = pd.read_excel('data_Phase3_1.xlsx')

# %%
df.head()
# Out:
#       Profit  Discount  Quantity      Sales  SalesAfterDiscount  \
# 0  45.975399       0.0         2  97.820000           97.820000
# 1  18.781200       0.0         2  39.959999           39.959999
# 2   5.225600       0.0         2  11.360000           11.360000
# 3  18.211201       0.0         2  37.939999           37.939999
# 4   8.920600       0.0         2  18.980000           18.980000
#
#    Shipping Cost       Ship Mode         Category      CategorySubcategory  \
# 0           7.78  Standard Class  Office Supplies  Office Supplies - Paper
# 1           3.77  Standard Class  Office Supplies  Office Supplies - Paper
# 2           0.79  Standard Class  Office Supplies  Office Supplies - Paper
# 3           3.86  Standard Class  Office Supplies  Office Supplies - Paper
# 4           1.30  Standard Class  Office Supplies  Office Supplies - Paper
#
#                                         Product Name  ... Order Priority  \
# 0                                         Xerox 1943  ...           High
# 1                                         Xerox 1884  ...         Medium
# 2              Green Bar Cards & Envelopes, Recycled  ...         Medium
# 3                                         Xerox 1912  ...         Medium
# 4  Tops 4 X 6 Fluorescent Color Memo Sheets, 500 ...  ...         Medium
#
#   Region        Country           City DayOfWeek IsWeekend  Day  Month  Year  \
# 0   east  united states  new york city         6      True   20      6  2014
# 1   east  united states  new york city         4     False    3      8  2011
# 2   east  united states  new york city         7      True   10     12  2011
# 3   east  united states  new york city         2     False   17      2  2014
# 4   east  united states  new york city         6      True   10     10  2014
#
#      Segment
# 0  Corporate
# 1   Consumer
# 2   Consumer
# 3   Consumer
# 4   Consumer
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49670 entries, 0 to 49669
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Profit               49670 non-null  float64
#  1   Discount             49670 non-null  float64
#  2   Quantity             49670 non-null  int64
#  3   Sales                49670 non-null  float64
#  4   SalesAfterDiscount   49670 non-null  float64
#  5   Shipping Cost        49670 non-null  float64
#  6   Ship Mode            49670 non-null  object
#  7   Category             49670 non-null  object
#  8   CategorySubcategory  49670 non-null  object
#  9   Product Name         49670 non-null  object
#  10  IsReturned           49670 non-null  object
#  11  Market               49670 non-null  object
#  12  Order Priority       49670 non-null  object
#  13  Region               49670 non-null  object
#  14  Country              49670 non-null  object
#  15  City                 49670 non-null  object
#  16  DayOfWeek            49670 non-null  int64
#  17  IsWeekend            49670 non-null  bool
#  18  Day                  49670 non-null  int64
#  19  Month                49670 non-null  int64
#  20  Year                 49670 non-null  int64
#  21  Segment              49670 non-null  object
# dtypes: bool(1), float64(5), int64(5), object(11)
# memory usage: 8.0+ MB

# %%
df.nunique().sort_values()
# Out:
# IsReturned                 2
# IsWeekend                  2
# Category                   3
# Segment                    3
# Order Priority             4
# Ship Mode                  4
# Year                       4
# Market                     7
# DayOfWeek                  7
# Month                     12
# Region                    13
# Quantity                  14
# CategorySubcategory       17
# Discount                  27
# Day                       31
# Country                  147
# City                    3590
# Product Name            3662
# Shipping Cost          16590
# Sales                  22513
# Profit                 24077
# SalesAfterDiscount     26413
# dtype: int64

# %% [markdown]
# <h2>تقسیم داده‌ها به آموزش و تست</h2>

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=8)

# %% [markdown]
# <h2>پیش‌پردازش داده‌ها و آماده‌سازی برای مدل‌سازی</h2>

# %%
train_data = train_data.drop(columns=["Product Name"])

print(train_data.columns.tolist())
# Out:
# ['Profit', 'Discount', 'Quantity', 'Sales', 'SalesAfterDiscount', 'Shipping Cost', 'Ship Mode', 'Category', 'CategorySubcategory', 'IsReturned', 'Market', 'Order Priority', 'Region', 'Country', 'City', 'DayOfWeek', 'IsWeekend', 'Day', 'Month', 'Year', 'Segment']

# %%
train_data['IsReturned'] = train_data['IsReturned'].map({'Yes': 1, 'No': 0})
train_data['IsReturned'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39736 entries, 16871 to 4547
# Series name: IsReturned
# Non-Null Count  Dtype
# --------------  -----
# 39736 non-null  int64
# dtypes: int64(1)
# memory usage: 620.9 KB

# %%
low = ['Ship Mode', 'Category', 'CategorySubcategory', 'Market', 'Order Priority', 'Region', 'Segment']
train_data = pd.get_dummies(train_data, columns=low, drop_first=True)

# %%
top_countries = train_data['Country'].value_counts().head(25).index
top_cities = train_data['City'].value_counts().head(25).index

# %%
train_data["Country"] = train_data["Country"].apply(lambda x: x if x in top_countries else 'Other')
train_data["City"] = train_data["City"].apply(lambda x: x if x in top_cities else 'Other')

train_data = pd.get_dummies(train_data, columns=['Country', 'City'], drop_first=True)

# %%
# نسبت تخفیف به فروش
train_data['DiscountRate'] = train_data['Discount'] / train_data['Sales']

# نسبت هزینه ارسال به فروش
train_data['ShippingRatio'] = train_data['Shipping Cost'] / train_data['Sales']

# تخفیف مؤثر روی قیمت نهایی
train_data['EffectiveDiscount'] = train_data['Sales'] - train_data['SalesAfterDiscount']

# نسبت فروش پس از تخفیف به فروش اصلی
train_data['NetSalesRatio'] = train_data['SalesAfterDiscount'] / train_data['Sales']

# %%
num_cols = ['Discount', 'Quantity', 'Sales', 'SalesAfterDiscount', 'Shipping Cost', 'DayOfWeek','DiscountRate','EffectiveDiscount', 'NetSalesRatio', 'Day',
            'Month', 'Year']

scaler = StandardScaler()
train_data[num_cols] = scaler.fit_transform(train_data[num_cols])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39736 entries, 16871 to 4547
# Columns: 110 entries, Profit to NetSalesRatio
# dtypes: bool(95), float64(14), int64(1)
# memory usage: 8.5 MB

# %%
y_train = train_data['Profit']
X_train = train_data.drop(columns=['Profit'])

# %% [markdown]
# <h2> تابع آماده‌سازی داده جدید برای پیش‌بینی</h2>

# %%
def preprocess_input_data(new_df, scaler, scaler_cols, top_countries, top_cities):
    if 'Product Name' in new_df.columns:
        new_df = new_df.drop(columns=['Product Name'])
    if 'ProfitMargin' in new_df.columns:
        new_df = new_df.drop(columns=['ProfitMargin'])
    new_df['IsReturned'] = new_df['IsReturned'].map({'Yes': 1, 'No': 0})
    new_df['IsWeekend'] = new_df['IsWeekend'].astype(int)

    new_df['DiscountRate'] = new_df['Discount'] / new_df['Sales']
    new_df['ShippingRatio'] = new_df['Shipping Cost'] / new_df['Sales']
    new_df['EffectiveDiscount'] = new_df['Sales'] - new_df['SalesAfterDiscount']
    new_df['NetSalesRatio'] = new_df['SalesAfterDiscount'] / new_df['Sales']


    low_cardinality = ['Ship Mode', 'Category', 'CategorySubcategory', 'Market', 'Order Priority', 'Region', 'Segment']
    new_df = pd.get_dummies(new_df, columns=low_cardinality, drop_first=True)

    for col, top_values in zip(['Country', 'City'], [top_countries, top_cities]):
        new_df[col] = new_df[col].apply(lambda x: x if x in top_values else 'Other')
    new_df = pd.get_dummies(new_df, columns=['Country', 'City'], drop_first=True)

    new_df[scaler_cols] = scaler.transform(new_df[scaler_cols])

    y = new_df['Profit']
    X = new_df.drop(columns=['Profit'])

    return X, y

# %%
X_test, y_test = preprocess_input_data(
    test_data,
    scaler,
    num_cols,
    top_countries,
    top_cities
)

# %% [markdown]
# <h2>مدل</h2>

# %%
models = {
    'Ridge': {
        'model': Ridge(),
        'params': {
            'alpha': [0.01, 0.1, 1, 10, 100]
        }
    },
    'GradientBoosting': {
        'model': GradientBoostingRegressor(),
        'params': {
            'n_estimators': [100, 200],
            'learning_rate': [0.01, 0.1],
            'max_depth': [3, 5]
        }
    },
    'RandomForest': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [100, 200],
            'max_depth': [5, 10, None],
            'min_samples_split': [2, 5]
        }
    },
    'XGBoost': {
        'model': XGBRegressor(),
        'params': {
            'n_estimators': [100, 200],
            'learning_rate': [0.01, 0.1],
            'max_depth': [3, 5],
            'reg_alpha': [0, 0.1],
            'reg_lambda': [1, 5]
        }
    }
}

# %%
best_models = {}

for model_name in models:
    model = models[model_name]['model']
    params = models[model_name]['params']

    search = GridSearchCV(model, params, cv=2, scoring='r2')
    search.fit(X_train, y_train)

    best_models[model_name] = {
        'model': search.best_estimator_,
        'score': search.best_score_,
        'params': search.best_params_
    }

    print(model_name, "r2:", search.best_score_ , "params:", search.best_params_)
# Out:
# Ridge r2: 0.6399756854045224 params: {'alpha': 10}
# GradientBoosting r2: 0.7115878810048883 params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
# RandomForest r2: 0.6813757440256922 params: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# XGBoost r2: 0.6595979149285331 params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 5}

# %%
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

print("\nارزیابی مدل‌ها روی داده تست:")
for model_name in best_models:
    model = best_models[model_name]['model']
    y_pred = model.predict(X_test)
    r2_test = r2_score(y_test, y_pred)
    print(model_name, "R2", r2_test)
# Out:
# ارزیابی مدل‌ها روی داده تست:
# Ridge R2 0.6479746027977105
# GradientBoosting R2 0.7433091717202123
# RandomForest R2 0.7399429362855161
# XGBoost R2 0.7372716757227535

# %%
final_model = best_models['GradientBoosting']['model']
result["model_name"] = 'GradientBoosting'
result["param_learning_rate"] = best_models['GradientBoosting']['params']["learning_rate"]
result["param_max_depth"] = best_models['GradientBoosting']['params']['max_depth']
result["param_n_estimators"] = best_models['GradientBoosting']['params']['n_estimators']
y_pred = final_model.predict(X_test)
r2_t = r2_score(y_test, y_pred)
mae_t = mean_absolute_error(y_test, y_pred)
mse_t = mean_squared_error(y_test, y_pred)
print("GradientBoosting:")
print("R²:", r2_t)
print("MAE:", mae_t)
print("MSE:", mse_t)
result["R2"] = r2_t
result["MAE"] = mae_t
result["MSE"] = mse_t
result_df = pd.DataFrame([result])
result_df.to_csv("result_Profit_model.csv", index=False)
# Out:
# GradientBoosting:
# R²: 0.7433091717202123
# MAE: 33.2799486220524
# MSE: 6660.139033121813

# %%
importances = final_model.feature_importances_
features = X_test.columns

importance_df = pd.DataFrame({'features': features, 'importances': importances})
importance_df = importance_df.sort_values(by='importances', ascending=False)
print(importance_df.head(30))
importance_df.to_csv("result_importances_profit_model.csv", index=False)
# Out:
#                                            features  importances
# 3                                SalesAfterDiscount     0.496496
# 107                               EffectiveDiscount     0.222274
# 2                                             Sales     0.088951
# 0                                          Discount     0.067455
# 108                                   NetSalesRatio     0.055297
# 105                                    DiscountRate     0.011126
# 21    CategorySubcategory_Office Supplies - Binders     0.009151
# 27   CategorySubcategory_Office Supplies - Supplies     0.007796
# 29         CategorySubcategory_Technology - Copiers     0.007362
# 4                                     Shipping Cost     0.005299
# 1                                          Quantity     0.002828
# 8                                               Day     0.002823
# 9                                             Month     0.002506
# 106                                   ShippingRatio     0.002361
# 57                                    Country_china     0.001404
# 38                              Order Priority_High     0.001170
# 79                            Country_united states     0.001090
# 30        CategorySubcategory_Technology - Machines     0.000881
# 102                                     City_sydney     0.000829
# 40                            Order Priority_Medium     0.000818
# 36                                     Market_LATAM     0.000805
# 39                               Order Priority_Low     0.000773
# 66                                    Country_india     0.000752
# 45                                      Region_east     0.000692
# 35                                        Market_EU     0.000649
# 18           CategorySubcategory_Furniture - Tables     0.000627
# 31          CategorySubcategory_Technology - Phones     0.000584
# 10                                             Year     0.000580
# 6                                         DayOfWeek     0.000534
# 53                                Segment_Corporate     0.000428

# %%
with open('gradient_boosting_profit_model.pkl', 'wb') as f:
    pickle.dump(final_model, f)
